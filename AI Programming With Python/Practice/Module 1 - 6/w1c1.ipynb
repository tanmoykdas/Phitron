# %%
a = 10
print (a)

b = 1.5
a = b
print(type(a))
# Out:
# 10
# <class 'float'>

# %%
a = input()
b = a.split()
print(b)
print(type(b))
print(type(a[0]))
for i in range(len(b)):
    b[i] = int(b[i])
print(b[0] + b[1])
# Out:
# ['1', '2', '3']
# <class 'list'>
# <class 'str'>
# 3

# %%
x = 5

if x > 3:
    print("kaka")
elif x > 1:
    print("mama")
else:
    print("caca")
# Out:
# kaka
