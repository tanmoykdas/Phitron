# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd 

lis = [10, 20, 30, 40, 50]

x = pd.DataFrame(lis, columns = ["value"])

x
# Out:
#    value
# 0     10
# 1     20
# 2     30
# 3     40
# 4     50

# %%
dic = {
    "Name" : ["tan", "al", "sena", "naim"],
    "Age" : [19, 20, 21, 22],
    "City": ["khulna", "natore", "capai", "bogura"]
}

dataset =  pd.DataFrame(dic)
dataset
# Out:
#    Name  Age    City
# 0   tan   19  khulna
# 1    al   20  natore
# 2  sena   21   capai
# 3  naim   22  bogura

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(f"Number or rows = {dataset.shape[0]}")
print(f"Number or rows = {dataset.shape[1]}")
print()
for i, row in dataset.iterrows():
    print(row)
    print()
dataset.describe()

dataset.dtypes
# Out:
# Number or rows = 4
# Number or rows = 3
#
# Name       tan
# Age         19
# City    khulna
# Name: 0, dtype: object
#
# Name        al
# Age         20
# City    natore
# Name: 1, dtype: object
#
# Name     sena
# Age        21
# City    capai
# Name: 2, dtype: object
#
# Name      naim
# Age         22
# City    bogura
# Name: 3, dtype: object
# Name    object
# Age      int64
# City    object
# dtype: object

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data = {
    'product': ['pen', 'book', 'eraser', 'pencil'],
    'price': [10, 50, 5, 7],
    'quantity': [100, 60, 200, 150]
}

df = pd.DataFrame(data)

print(df.index)
df.columns
df.head(1)
# Out:
# RangeIndex(start=0, stop=4, step=1)
#   product  price  quantity
# 0     pen     10       100

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.iloc[0]
# Out:
# product     pen
# price        10
# quantity    100
# Name: 0, dtype: object

# %%
df.loc[:,"price"]
# Out:
# 0    10
# 1    50
# 2     5
# 3     7
# Name: price, dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
marks = {
    'name': ['tanmoy', 'rahat', 'jubayer'],
    'cce': [60, 65, 70],
    'csit': [70, 72, 75],
    'eee': [90, 93, 99]
}

mark = pd.DataFrame(marks)

mark
# Out:
#       name  cce  csit  eee
# 0   tanmoy   60    70   90
# 1    rahat   65    72   93
# 2  jubayer   70    75   99

# %%
new_mark = mark.drop(columns="cce")

new_mark
# Out:
#       name  csit  eee
# 0   tanmoy    70   90
# 1    rahat    72   93
# 2  jubayer    75   99

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
employees = {
    'Name': ['a', 'x', 'j', 'd'],
    'Department': ['cce', 'csit', 'eee', 'pme'],
    'Salary': [100, 300, 400, 50]
}

emp = pd.DataFrame(employees)

emp
# Out:
#   Name Department  Salary
# 0    a        cce     100
# 1    x       csit     300
# 2    j        eee     400
# 3    d        pme      50

# %%
x = emp.sort_values('Salary', ascending= True) #salary ascendin

x
# Out:
#   Name Department  Salary
# 3    d        pme      50
# 0    a        cce     100
# 1    x       csit     300
# 2    j        eee     400

# %%
y = emp.sort_values('Name', ascending=False)

y
# Out:
#   Name Department  Salary
# 1    x       csit     300
# 2    j        eee     400
# 3    d        pme      50
# 0    a        cce     100

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
student = {
    'name' : ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'],
    'score': [10, 20, 80, 70, 55, 77, 11, 100]
}

st = pd.DataFrame(student)

st
# Out:
#   name  score
# 0    a     10
# 1    b     20
# 2    c     80
# 3    d     70
# 4    e     55
# 5    f     77
# 6    g     11
# 7    h    100

# %%
filtered = st.loc[(st["score"] > 40) & (st["score"] < 60)]

filtered
# Out:
#   name  score
# 4    e     55
